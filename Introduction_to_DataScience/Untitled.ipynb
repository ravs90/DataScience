# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

# %%
df.head()
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
# You should write your whole answer within the function provided. The autograder will call
# this function and compare the return value against the correct solution value
def answer_zero():
    # This function returns the row for Afghanistan, which is a Series object. The assignment
    # question description will tell you the general format the autograder is expecting
    return df.iloc[0]

# You can examine what your function returns by calling it in the cell. If you have questions
# about the assignment formats, check out the discussion forums for any FAQs
answer_zero()
# Out:
# # Summer           13
# Gold                0
# Silver              0
# Bronze              2
# Total               2
# # Winter            0
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# # Games            13
# Gold.2              0
# Silver.2            0
# Bronze.2            2
# Combined total      2
# ID                AFG
# Name: Afghanistan, dtype: object

# %%
#df['Gold']==df['Gold'].max()
#dq = df[df['Gold']==df['Gold'].max()].reset_index()
#dq = df[df['Gold']==df['Gold'].idmax()].reset_index()
#df.loc[df['Gold'].idxmax()]
#dq.rename(columns={'index':'country'}, inplace=True)
#dq['country'].iloc[0]
#print '%s' % (dq['ID'])
#dq.filter(['index'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-e78a34bb62a0> in <module>()
#       5 #dq.rename(columns={'index':'country'}, inplace=True)
#       6 #dq['country'].iloc[0]
# ----> 7 dq(0).iloc[0]
#       8 #print '%s' % (dq['ID'])
#       9 #dq.filter(['index'],axis=1)
#
# TypeError: 'DataFrame' object is not callable

# %%
### Question 2
#Which country had the biggest difference between their summer and winter gold medal counts?

#*This function should return a single string value.*
#df.head()
dw = df[(df['Gold']-df['Gold.1']).abs() == (df['Gold']-df['Gold.1']).abs().max()].reset_index()

dw.rename(columns={'index':'country'}, inplace=True)
dw['country'].iloc[0]
#dw1=pd.DataFrame([dw])
# Out:
# 'United States'

# %%
### Question 3
Which country has the biggest difference between their summer gold medal counts and winter gold medal counts relative to their total gold medal count? 

$$\frac{Summer~Gold - Winter~Gold}{Total~Gold}$$

Only include countries that have won at least 1 gold in both summer and winter.

*This function should return a single string value.*
# Out:
#   File "<ipython-input-139-bebede102996>", line 2
#     Which country has the biggest difference between their summer gold medal counts and winter gold medal counts relative to their total gold medal count?
#                 ^
# SyntaxError: invalid syntax

# %%
df_n = df[(df['Gold'] > 0) & (df['Gold.1'] > 0)]
dq=df_n[((df_n['Gold']-df_n['Gold.1'])/df_n['Gold.2']).abs()==((df_n['Gold']-df_n['Gold.1'])/df_n['Gold.2']).abs().max()].reset_index()
dq.rename(columns={'index':'country'}, inplace=True)
dq['country'].iloc[0]
# Out:
# 'Bulgaria'

# %%
### Question 4
Write a function that creates a Series called "Points" which is a weighted value where each gold medal (`Gold.2`) counts for 3 points, silver medals (`Silver.2`) for 2 points, and bronze medals (`Bronze.2`) for 1 point. The function should return only the column (a Series object) which you created, with the country names as indices.

*This function should return a Series named `Points` of length 146*
# Out:
#   File "<ipython-input-168-65ee5c3f56f2>", line 2
#     Write a function that creates a Series called "Points" which is a weighted value where each gold medal (`Gold.2`) counts for 3 points, silver medals (`Silver.2`) for 2 points, and bronze medals (`Bronze.2`) for 1 point. The function should return only the column (a Series object) which you created, with the country names as indices.
#           ^
# SyntaxError: invalid syntax

# %%
Points = pd.Series(df['Gold.2']*3+df['Silver.2']*2+df['Bronze.2']*1)
len(Points)
# Out:
# 146

# %%
# Out:
# Afghanistan                            2
# Algeria                               27
# Argentina                            130
# Armenia                               16
# Australasia                           22
# Australia                            923
# Austria                              569
# Azerbaijan                            43
# Bahamas                               24
# Bahrain                                1
# Barbados                               1
# Belarus                              154
# Belgium                              276
# Bermuda                                1
# Bohemia                                5
# Botswana                               2
# Brazil                               184
# British West Indies                    2
# Bulgaria                             411
# Burundi                                3
# Cameroon                              12
# Canada                               846
# Chile                                 24
# ...

# %%
census_df = pd.read_csv('census.csv')
census_df
td=census_df[census_df['SUMLEV'] == 50]
td.head()
#td.loc[:,'POPESTIMATE2010':'POPESTIMATE2015']
#td[td['STNAME']=='Alabama']['CENSUS2010POP'].max()
#td_1=td.groupby(['STNAME'])
#g=td_1['CENSUS2010POP']
#g.nlargest(3)
#td_1=td.groupby(['STNAME']).count().reset_index()
#td_2 = td_1[td_1['SUMLEV']==td_1['SUMLEV'].max()]
#td_2['STNAME']
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
td_new = pd.DataFrame()
td_new['CTYNAME'] = td[['CTYNAME']].max(axis=1)
td_new['MaxPopulation'] = td[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']].max(axis=1)
td_new['MinPopulation'] = td[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']].min(axis=1)
td_new['abs_diff'] = td_new['MaxPopulation']-td_new['MinPopulation']
td_new.head()
tn=td_new.sort_values(['abs_diff'],ascending=False).head(1)
tn['CTYNAME'].iloc[0]
# Out:
# 'Harris County'

# %%
import pandas as pd
census_df = pd.read_csv('census.csv')
census_df
td=census_df[((census_df['REGION'] == 1) | ( census_df['REGION'] == 2)) & (census_df['SUMLEV']==50) & (census_df['POPESTIMATE2015'] > census_df['POPESTIMATE2014']) & (census_df['CTYNAME'].str.startswith('Washington'))]
td_new = td[['STNAME','CTYNAME']]
td_new.head()
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County

# %%
import pandas as pd
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
import pandas as pd
products_df = pd.DataFrame([{'Product ID': '4109', 'Price': '5.0', 'Product': 'Sushi Roll'},
                         {'Product ID': '1412', 'Price': '0.5', 'Product': 'Egg'},
                         {'Product ID': '8931', 'Price': '1.5', 'Product': 'Bagel'}])
products_df.set_index('Product ID')
# Out:
#            Price     Product
# Product ID
# 4109         5.0  Sushi Roll
# 1412         0.5         Egg
# 8931         1.5       Bagel

# %%
invoices_df = pd.DataFrame([{'Customer': 'Ali', 'Product ID': '4109', 'Quantity': '1'},
                         {'Customer': 'Eric', 'Product ID': '1412', 'Quantity': '12'},
                         {'Customer': 'Ande', 'Product ID': '8931', 'Quantity': '6'},
                           {'Customer': 'Sam', 'Product ID': '4109', 'Quantity': '2'}])
invoices_df
# Out:
#   Customer Product ID Quantity
# 0      Ali       4109        1
# 1     Eric       1412       12
# 2     Ande       8931        6
# 3      Sam       4109        2

# %%
invoice_price_df = pd.merge(invoices_df,products_df,how='inner', left_on='Product ID', right_on='Product ID')
invoice_price_df 
#invoice_price_df['Total Cost']=invoice_price_df['Quantity']*invoice_price_df['Price']

#type(invoice_price_df['Quantity'])
# Out:
#   Customer Product ID Quantity Price     Product
# 0      Ali       4109        1   5.0  Sushi Roll
# 1      Sam       4109        2   5.0  Sushi Roll
# 2     Eric       1412       12   0.5         Egg
# 3     Ande       8931        6   1.5       Bagel

# %%
(invoice_price_df['Quantity']).astype(float)*(invoice_price_df['Price']).astype(float)
# Out:
# 0     5.0
# 1    10.0
# 2     6.0
# 3     9.0
# dtype: float64

# %%
invoice_price_df['Total Cost']=(invoice_price_df['Quantity']).astype(float)*(invoice_price_df['Price']).astype(float)
invoice_price_df
# Out:
#   Customer Product ID Quantity Price     Product  Total Cost
# 0      Ali       4109        1   5.0  Sushi Roll         5.0
# 1      Sam       4109        2   5.0  Sushi Roll        10.0
# 2     Eric       1412       12   0.5         Egg         6.0
# 3     Ande       8931        6   1.5       Bagel         9.0

# %%
print(df.drop(df[df['Quantity'] == 0].index).rename(columns={'Weight': 'Weight (oz.)'}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-71234f72ddf4> in <module>()
# ----> 1 print(df.drop(df[df['Quantity'] == 0].index).rename(columns={'Weight': 'Weight (oz.)'}))
#
# NameError: name 'df' is not defined

# %%
print(df.groupby('Category').apply(lambda df,a,b: sum(df[a] * df[b]), 'Weight (oz.)', 'Quantity'))


# Or alternatively without using a lambda:
# def totalweight(df, w, q):
#        return sum(df[w] * df[q])
#        
# print(df.groupby('Category').apply(totalweight, 'Weight (oz.)', 'Quantity'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-411a41688c85> in <module>()
# ----> 1 print(df.groupby('Category').apply(lambda df,a,b: sum(df[a] * df[b]), 'Weight (oz.)', 'Quantity'))
#       2
#       3
#       4 # Or alternatively without using a lambda:
#       5 # def totalweight(df, w, q):
#
# NameError: name 'df' is not defined

# %%
s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low']).astype('category',categories=['Low', 'Medium', 'High'],
                             ordered=True)
print(s>'Low')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-24836bb8f20e> in <module>()
# ----> 1 s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low']).astype('category',categories=['Low', 'Medium', 'High'],
#       2                              ordered=True)
#       3 print(s>'Low')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Energy+Indicators.xls', 'Energy', index_col=None, na_values=['NA'],header=1, skipfooter=38, skipheader=0, skiprows=16, usecols="C:F",names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable'])
df
# Out:
#                                                Country Energy Supply  \
# 0                                          Afghanistan           321
# 1                                              Albania           102
# 2                                              Algeria          1959
# 3                                       American Samoa           ...
# 4                                              Andorra             9
# 5                                               Angola           642
# 6                                             Anguilla             2
# 7                                  Antigua and Barbuda             8
# 8                                            Argentina          3378
# 9                                              Armenia           143
# 10                                               Aruba            12
# 11                                          Australia1          5386
# 12                                             Austria          1391
# ...

# %%
df.replace("...",np.NaN,inplace=True)
df
#df['Energy Supply']=df['Energy Supply'].apply(lambda x:x*(1000000))
#df['Energy Supply']=df['Energy Supply']*1000000
# Out:
#                                                Country  Energy Supply  \
# 0                                          Afghanistan          321.0
# 1                                              Albania          102.0
# 2                                              Algeria         1959.0
# 3                                       American Samoa            NaN
# 4                                              Andorra            9.0
# 5                                               Angola          642.0
# 6                                             Anguilla            2.0
# 7                                  Antigua and Barbuda            8.0
# 8                                            Argentina         3378.0
# 9                                              Armenia          143.0
# 10                                               Aruba           12.0
# 11                                          Australia1         5386.0
# ...

# %%
df['Energy Supply']=df['Energy Supply'].apply(lambda x:x*(1000000))
df.head()
# Out:
#           Country                                      Energy Supply  \
# 0     Afghanistan                                          321000000
# 1         Albania                                          102000000
# 2         Algeria                                         1959000000
# 3  American Samoa  .................................................
# 4         Andorra                                            9000000
#
#   Energy Supply per Capita  % Renewable
# 0                       10    78.669280
# 1                       35   100.000000
# 2                       51     0.551010
# 3                      ...     0.641026
# 4                      121    88.695650

# %%
#df.Country[df.Country=='Republic of Korea']="South Korea"
df['Country'] = df['Country'].str.replace('\d+', '')
#df.replace("Republic of Korea","South Korea",inplace=True)
#df.replace("United States of America20", "United States",inplace=True)
#df.replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom",inplace=True)
#df.replace("China, Hong Kong Special Administrative Region", "Hong Kong",inplace=True)

# %%
df
#df[df["Country"]=="Republic of Korea*"]
df.replace("United States of America20", "United States",inplace=True)
df.replace("Republic of Korea","South Korea",inplace=True)
df.replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom",inplace=True)
df.replace("China, Hong Kong Special Administrative Region", "Hong Kong",inplace=True)
df
# Out:
#                                        Country  \
# 0                                  Afghanistan
# 1                                      Albania
# 2                                      Algeria
# 3                               American Samoa
# 4                                      Andorra
# 5                                       Angola
# 6                                     Anguilla
# 7                          Antigua and Barbuda
# 8                                    Argentina
# 9                                      Armenia
# 10                                       Aruba
# 11                                   Australia
# 12                                     Austria
# 13                                  Azerbaijan
# 14                                     Bahamas
# 15                                     Bahrain
# 16                                  Bangladesh
# 17                                    Barbados
# 18                                     Belarus
# ...

# %%
import pandas as pd
import numpy as np
energy = pd.read_excel('Energy+Indicators.xls', 'Energy', index_col=None, na_values=['NA'],header=1, skipfooter=38, skipheader=0, skiprows=16, usecols="C:F",names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable'])
energy.replace("...",np.NaN,inplace=True)
energy['Energy Supply']=energy['Energy Supply'].apply(lambda x:x*(1000000))
energy['Country'] = energy['Country'].str.replace('\d+', '')
#either this regex or next one both works
#energy['CountryTest'] = energy['Country'].str.replace(r"\(.*\)","")
energy['Country'] = energy['Country'].str.replace("\([a-zA-Z\s]*\)","")
energy.replace("United States of America", "United States",inplace=True)
energy.replace("Republic of Korea","South Korea",inplace=True)
energy.replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom",inplace=True)
energy.replace("China, Hong Kong Special Administrative Region", "Hong Kong",inplace=True)
#energy
energyNew = energy.set_index('Country')
energyNew
# Out:
#                                            Energy Supply  \
# Country
# Afghanistan                                 3.210000e+08
# Albania                                     1.020000e+08
# Algeria                                     1.959000e+09
# American Samoa                                       NaN
# Andorra                                     9.000000e+06
# Angola                                      6.420000e+08
# Anguilla                                    2.000000e+06
# Antigua and Barbuda                         8.000000e+06
# Argentina                                   3.378000e+09
# Armenia                                     1.430000e+08
# Aruba                                       1.200000e+07
# Australia                                   5.386000e+09
# Austria                                     1.391000e+09
# Azerbaijan                                  5.670000e+08
# Bahamas                                     4.500000e+07
# ...

# %%
#df['CountryTest'] = df['Country'].str.replace(r"\(.*\)","")
#df['CountryTest'] = df['Country'].str.replace("\([a-zA-Z\s]*\)","")

# %%
gdp=pd.read_csv('world_bank.csv', index_col=0, skiprows=3, header=1)
gdp.replace("Korea, Rep.", "South Korea",inplace=True)
gdp.replace("Iran, Islamic Rep.", "Iran",inplace=True)
gdp.replace("Hong Kong SAR, China", "Hong Kong",inplace=True)
#gdp
gdpLast10 = gdp.filter(['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'])
#gdpLast10 = gdpLast10.rename(columns={'CountryName': 'Country'})

gdpLast10.index.names = ['Country']
gdpLast10
# Out:
#                                                            2006          2007  \
# Country Name
# Aruba                                                       NaN           NaN
# Andorra                                            4.018196e+09  4.021331e+09
# Afghanistan                                        1.030523e+10  1.172119e+10
# Angola                                             5.581103e+10  6.842044e+10
# Albania                                            9.771760e+09  1.034829e+10
# Arab World                                         1.763824e+12  1.863481e+12
# United Arab Emirates                               2.789489e+11  2.878318e+11
# Argentina                                          3.788140e+11  4.089887e+11
# Armenia                                            8.679746e+09  9.873142e+09
# American Samoa                                              NaN           NaN
# Antigua and Barbuda                                1.268714e+09  1.389229e+09
# ...

# %%
gdp.shape
# Out:
# (264, 59)

# %%
ScimEn=pd.read_excel('scimagojr-3.xlsx', 'Sheet1', index_col=None, na_values=['NA'],header=0)
#ScimEn
ScimEnTop15 = ScimEn.loc[ScimEn['Rank'] <= 15]
ScimEnTop15 = ScimEnTop15.set_index('Country')
ScimEnTop15
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
ScimEn.shape
# Out:
# (191, 8)

# %%
mergeOne = pd.merge(ScimEnTop15,energyNew, how='left', left_index=True, right_index=True)
mergeOne
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
mergeTwo = pd.merge(mergeOne, gdpLast10, how='left', left_index=True, right_index=True)
mergeTwo
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
ScimEnAll = ScimEn.set_index('Country')

# %%
ScimEnAll
# Out:
#                                 Rank  Documents  Citable documents  Citations  \
# Country
# China                              1     127050             126767     597237
# United States                      2      96661              94747     792274
# Japan                              3      30504              30287     223024
# United Kingdom                     4      20944              20357     206091
# Russian Federation                 5      18534              18301      34266
# Canada                             6      17899              17620     215003
# Germany                            7      17027              16831     140566
# India                              8      15005              14841     128763
# France                             9      13153              12973     130632
# South Korea                       10      11983              11923     114675
# Italy                             11      10964              10794     111850
# ...

# %%
ScimEnAll = ScimEn.set_index('Country')
mergeOne = pd.merge(ScimEnAll,energyNew, how='outer', left_index=True, right_index=True)
mergeTwo = pd.merge(mergeOne, gdpLast10, how='outer', left_index=True, right_index=True)
mergeTwo.shape
# Out:
# (324, 20)

# %%
lostentries = mergeTwo.shape[0]-15
lostentries
# Out:
# 309

# %%
mergeOne = pd.merge(ScimEnTop15,energyNew, how='left', left_index=True, right_index=True)
mergeTwo = pd.merge(mergeOne, gdpLast10, how='left', left_index=True, right_index=True)
rows = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
s = mergeTwo.apply(lambda x: np.average(x[rows]), axis=1)
s.sort_values(ascending=False, inplace=True)
s
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea                    NaN
# Iran                           NaN
# dtype: float64

# %%
s.index[5]
# Out:
# 'United Kingdom'

# %%
#nwm = mergeTwo.loc(mergeTwo['Country']=='United Kingdom')
#mergeTwo.index['Country']=='United Kingdom'
s2=mergeTwo.loc['United Kingdom']
df= s2.to_frame().T
max_value = df[["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]].max(axis=1)
min_value = df[["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]].min(axis=1)
#print(max_value)
#print(min_value)
#print(max_value-min_value)
(max_value-min_value).iloc[0]
# Out:
# United Kingdom    2.992858e+11
# dtype: float64
# 299285784765.13965

# %%
df.pivot_table( index='United Kingdom',aggfunc=[np.mean,np.min])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-96-0b78a0ffd03e> in <module>()
# ----> 1 df.pivot_table( index='United Kingdom',aggfunc=[np.mean,np.min])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    4466                            aggfunc=aggfunc, fill_value=fill_value,
#    4467                            margins=margins, dropna=dropna,
# -> 4468                            margins_name=margins_name)
#    4469
#    4470     def stack(self, level=-1, dropna=True):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      37                                 columns=columns,
# ...

# %%
def answer_one():
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy+Indicators.xls', 'Energy', index_col=None, na_values=['NA'],header=1, skipfooter=38, skipheader=0, skiprows=16, usecols="C:F",names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable'])
    energy.replace("...",np.NaN,inplace=True)
    energy['Energy Supply']=energy['Energy Supply'].apply(lambda x:x*(1000000))
    energy['Country'] = energy['Country'].str.replace('\d+', '')
    #either this regex or next one both works
    #energy['CountryTest'] = energy['Country'].str.replace(r"\(.*\)","")
    energy['Country'] = energy['Country'].str.replace("\([a-zA-Z\s]*\)","")
    energy.replace("United States of America", "United States",inplace=True)
    energy.replace("Republic of Korea","South Korea",inplace=True)
    energy.replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom",inplace=True)
    energy.replace("China, Hong Kong Special Administrative Region", "Hong Kong",inplace=True)
    energy
    #first dataframe built, start building second one
    gdp=pd.read_csv('world_bank.csv', index_col=0, skiprows=3, header=1)
    gdp.replace("Korea, Rep.", "South Korea",inplace=True)
    gdp.replace("Iran, Islamic Rep.", "Iran",inplace=True)
    gdp.replace("Hong Kong SAR, China", "Hong Kong",inplace=True)
    gdp
    #second dataframe built, start building third one
    ScimEn=pd.read_excel('scimagojr-3.xlsx', 'Sheet1', index_col=None, na_values=['NA'],header=0)
    ScimEn
    #get the top 15 rank rows
    ScimEnTop15 = ScimEn.loc[ScimEn['Rank'] <= 15]
    #get last 10 years gdp data
    gdpLast10 = gdp.filter(['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'])
    #set gdpLast10 index name as Country
    gdpLast10.index.names = ['Country']
    #get top 15 ranks and set index as Country
    ScimEnTop15 = ScimEn.loc[ScimEn['Rank'] <= 15]
    ScimEnTop15 = ScimEnTop15.set_index('Country')
    #
    energyNew = energy.set_index('Country')
    #
    mergeOne = pd.merge(ScimEnTop15,energyNew, how='left', left_index=True, right_index=True)
    mergeTwo = pd.merge(mergeOne, gdpLast10, how='left', left_index=True, right_index=True)

    return mergeTwo

# %%
answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
import numpy as np
Top15 = answer_one()
rows=['Energy Supply per Capita']
s = Top15.apply(lambda x: np.mean(x[rows]), axis=1)
print(s)
s
2+3
# Out:
# Country
# China                  93.0
# United States         286.0
# Japan                 149.0
# United Kingdom        124.0
# Russian Federation    214.0
# Canada                296.0
# Germany               165.0
# India                  26.0
# France                166.0
# South Korea           221.0
# Italy                 109.0
# Spain                 106.0
# Iran                    NaN
# Australia             231.0
# Brazil                 59.0
# dtype: float64
# 5

# %%
Top15 = answer_one()
Top15["Energy Supply per Capita"].mean()
# Out:
# 160.35714285714286

# %%
result = Top15.sort_values('% Renewable', ascending=False )
df = result.reset_index()
tuple(df[['Country','% Renewable']].iloc[0])
#result.iloc[0].reset_index()
#s = result.iloc[0]
#s['% Renewable']
#result.reset_index().iloc[0]
#result.iloc[0]
#r = result.iloc[0].reset_index()
#r = result.reset_index().iloc[0]
#r = r.reset_index()
#r
#tuple(r.iloc[0],r.iloc[10])
# Out:
# ('Brazil', 69.64803)

# %%
Top15 = answer_one()
Top15['ratio'] = Top15['Self-citations']/Top15['Citations']
result = Top15.sort_values('ratio', ascending=False )
df = result.reset_index()
tuple(df[['Country','ratio']].iloc[0])
# Out:
# ('China', 0.6893126179389422)

# %%
Top15 = answer_one()
Top15['estimate_population'] = Top15['Energy Supply']/Top15['Energy Supply per Capita']
result = Top15.sort_values('estimate_population', ascending=False )
df = result.reset_index()
tuple_result = tuple(df[['Country','estimate_population']].iloc[3])
# Out:
# ('Brazil', 205915254.23728815)

# %%
Top15 = answer_one()
Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
Top15['Citable docs per Capita'] = Top15['Citable documents'] / Top15['PopEst']
Top15['Citable docs per Capita'].corr(Top15['Energy Supply per Capita'])
# Out:
# 0.7901935488300877

# %%
import pandas as pd
Top15 = answer_one()
Top15['result'] = np.where(Top15['% Renewable'] >= Top15['% Renewable'].median(),1,0)
Top15 = Top15.sort_values('Rank', ascending=False)
Top15 = Top15.reset_index()
Top15
#ndf=Top15[['result']]
#ndf = ndf.reset_index()
#pd.Series(ndf)
s = pd.Series(Top15['result'].values, index=Top15['Country'], name='HighRenew')
s
# Out:
# Country
# Brazil                1
# Australia             0
# Iran                  0
# Spain                 1
# Italy                 1
# South Korea           0
# France                0
# India                 0
# Germany               1
# Canada                1
# Russian Federation    1
# United Kingdom        0
# Japan                 0
# United States         0
# China                 1
# Name: HighRenew, dtype: int64

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
Top15 = answer_one()
Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
Top15.groupby(by=ContinentDict,axis=0).aggregate({'1': np.average})
#df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# ...

# %%
grouped = Top15.groupby(by=ContinentDict,axis=0)
grouped.aggregate(np.mean)
# Out:
#                Rank     Documents  Citable documents      Citations  \
# Asia            7.0  38687.600000       38527.400000  224233.800000
# Australia      14.0   8831.000000        8725.000000   90765.000000
# Europe          8.0  15008.333333       14764.333333  124456.833333
# North America   4.0  57280.000000       56183.500000  503638.500000
# South America  15.0   8668.000000        8596.000000   60702.000000
#
#                Self-citations  Citations per document  H index  Energy Supply  \
# Asia                 110433.2                   7.324    112.6   4.759425e+10
# Australia             15606.0                  10.280    107.0   5.386000e+09
# Europe                26158.0                   8.860    109.5   1.232333e+10
# North America        153183.0                  10.105    189.5   5.063450e+10
# South America         14396.0                   7.000     86.0   1.214900e+10
#
#                Energy Supply per Capita  % Renewable      ...       \
# ...
